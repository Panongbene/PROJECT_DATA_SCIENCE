# %% [markdown]
# # <center>STUDENT AT PARYS SACLAY 25 OCTOBER 2020</center>#
# # <center> Programming Project Document Similarity</center>#
# #  NAMES: PANONGBENE JEAN MOHAMED SAWADOGO #
# # Email: amet1900@gmail.com #
# # Github: https://github.com/Panongbene #

# %%
import numpy as np
import pandas as pd
import altair as alt
import streamlit as st

# %%
# load the data
green_house_gas_1990_2018 =pd.read_csv('AIR_GHG_20102020181153462.csv')

# %%
# extract the agriculture polution 
df_agriculture = green_house_gas_1990_2018[green_house_gas_1990_2018["VAR"] =="AGR_P"]

# %%
alt.Chart(df_agriculture).mark_area().encode(
    x='Year',
    y='Value',
    color='Country'
)
# Out:
# alt.Chart(...)

# %%
import requests
from io import StringIO

orig_url= "https://drive.google.com/file/d/1S3mE7-CWL1Hve0GVpGmpBPSTdMkOYNRL/view?usp=sharing"

file_id = orig_url.split('/')[-2]
dwn_url='https://drive.google.com/uc?export=download&id=' + file_id
url = requests.get(dwn_url).text
csv_raw = StringIO(url)
dfs = pd.read_csv(csv_raw)
dfs.rename(columns={'ï»¿"COU"': 'COU'}, inplace=True)

print(dfs.head())
# Out:
#    COU    Country  POL         Pollutant    VAR  \
# 0  AUS  Australia  GHG  Greenhouse gases  TOTAL
# 1  AUS  Australia  GHG  Greenhouse gases  TOTAL
# 2  AUS  Australia  GHG  Greenhouse gases  TOTAL
# 3  AUS  Australia  GHG  Greenhouse gases  TOTAL
# 4  AUS  Australia  GHG  Greenhouse gases  TOTAL
#
#                             Variable   YEA  Year   Unit Code  \
# 0  Total  emissions excluding LULUCF  1990  1990  T_CO2_EQVT
# 1  Total  emissions excluding LULUCF  1991  1991  T_CO2_EQVT
# 2  Total  emissions excluding LULUCF  1992  1992  T_CO2_EQVT
# 3  Total  emissions excluding LULUCF  1993  1993  T_CO2_EQVT
# 4  Total  emissions excluding LULUCF  1994  1994  T_CO2_EQVT
#
#                        Unit  PowerCode Code  PowerCode  Reference Period Code  \
# 0  Tonnes of CO2 equivalent               3  Thousands                    NaN
# 1  Tonnes of CO2 equivalent               3  Thousands                    NaN
# ...

# %%
from google.colab import files
uploaded = files.upload()

# To store dataset in a Pandas Dataframe
import io
df2 = pd.read_csv(io.BytesIO(uploaded["https://drive.google.com/file/d/1S3mE7-CWL1Hve0GVpGmpBPSTdMkOYNRL/view?usp=sharing"]))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-196-b87333a4a177> in <module>
# ----> 1 from google.colab import files
#       2 uploaded = files.upload()
#       3
#       4 # To store dataset in a Pandas Dataframe
#       5 import io
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
country_data_fram = green_house_gas_1990_2018[green_house_gas_1990_2018["Variable"] == '3 - Agriculture']

# %%
alt.Chart(country_data_fram).mark_bar().encode(
    x='Country',
    y='mean(Value)',
    color='Year:N'
)
# Out:
# alt.Chart(...)

# %%
kk = green_house_gas_1990_2018[green_house_gas_1990_2018["Year"] == 2018]
np.sum(kk[kk['Country']=='Luxembourg'].Value)
# Out:
# 94654270.78599997

# %%
Pollution_per_Variable = dict()
tab_variable = df_greenhouse_gas["Variable"].unique()
for i in tab_variable:
    Pollution_per_Variable[i] = np.abs(np.sum(df_greenhouse_gas[df_greenhouse_gas["Variable"] == i].Value))
    
Pollution_per_Variable = pd.DataFrame(list(Pollution_per_Variable.items()), columns=['Name Variable', 'Total Polution'])

# %%
Pollution_per_Variable
# Out:
#                                        Name Variable  Total Polution
# 0                  Total  emissions excluding LULUCF    2.077187e+09
# 1             Total GHG excl. LULUCF, Index 1990=100    1.852659e+09
# 2                  Total GHG excl. LULUCF per capita    1.369096e+04
# 3                                          5 - Waste    4.597132e+07
# 4            2- Industrial processes and product use    1.029898e+08
# 5                                         1 - Energy    1.075482e+09
# 6                                    3 - Agriculture    1.311422e+08
# 7                                          6 - Other    1.290742e+03
# 8             Total GHG excl. LULUCF per unit of GDP    5.047250e+02
# 9                            1A1 - Energy Industries    4.101026e+08
# 10   Land use, land-use change and forestry (LULUCF)    7.679900e+07
# 11               1A4 - Residential and other sectors    1.559090e+08
# 12                              1A5 - Energy - Other    1.740788e+07
# ...

# %%
Transport_data_fram = green_house_gas_1990_2018[green_house_gas_1990_2018["Variable"] == "1C - CO2 from Transport and Storage"]
#Transport_data_fram = green_house_gas_1990_2018[green_house_gas_1990_2018["Variable"] == "1A3 - Transport"]

# %%
alt.Chart(Transport_data_fram).mark_area().encode(
    x='Year',
    y='mean(Value)',
    color='Country:N'
)
# Out:
# alt.Chart(...)

# %%
Cette courbe senser montrer la dimunion au file au file du temps de l'emmission des gaz à effet de serre dans le
secteur du transport dans les pays de l'ocde reponde au critère de P2.

En effet, les données visualisées ne sont pas les données du secteur du transport proprement dites, nous avons pris
les données du secteur du transport plus les données du secteur du stockage pour construire la courbe. On l'a mentionné
de manière nuancée dans notre titre en disant que c'est les données du secteur du transport plus d'autres élément.

Aussi, les pays representés ne sont pas tous les pays de l'OECD. En effet, on a représenté juste 5 courbes surface
le premier est le canada, le deuxieme est le Norway, le troisieme est la turkey et le 4 est la moyenne des données sur 
les pays de l'EURE et le cinquieme la moyenne des données sur les pays de l'OECD. Le choix a été faite de sorte d'avoir 
une courbe qui va décroitre à la fin.

L'outil de visualisation utilisé aussi a été nuancé, en effet avec la visualisation par les surfaces imbriquées, 
il est plus difficile  d'avoir une réel comprehension et ca demande de faire des efforts pour comprembre ce dont on parle.

# %%
alt.Chart(Pollution_per_Variable).mark_bar().encode(
    x='Name Variable',
    y='Total Polution',
    )
# Out:
# alt.Chart(...)

# %%
ddd = green_house_gas_1990_2018[green_house_gas_1990_2018["Year"] == 1990]
alt.Chart(ddd).mark_bar().encode(
    x='Variable',
    y='Value',
    color='Country'
)
# Out:
# alt.Chart(...)

# %%
# Out:
# Empty DataFrame
# Columns: [COU, Country, POL, Pollutant, VAR, Variable, YEA, Year, Unit Code, Unit, PowerCode Code, PowerCode, Reference Period Code, Reference Period, Value, Flag Codes, Flags]
# Index: []

# %%
green_house_gas_1990_2018
# Out:
#        COU     Country  POL         Pollutant         VAR  \
# 0      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 1      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 2      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 3      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 4      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 5      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 6      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 7      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 8      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 9      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 10     AUS   Australia  GHG  Greenhouse gases       TOTAL
# 11     AUS   Australia  GHG  Greenhouse gases       TOTAL
# 12     AUS   Australia  GHG  Greenhouse gases       TOTAL
# 13     AUS   Australia  GHG  Greenhouse gases       TOTAL
# 14     AUS   Australia  GHG  Greenhouse gases       TOTAL
# ...

# %%
#df['VAR'].value_counts()

# %%
#countries=df['Country'].unique()
#df_agriculture = df[df["VAR"] =="AGR_P"]

#total_value_pollution_country_agriculture = dict()
#for i in countries:
#    total_value_pollution_country_agriculture[i]=np.sum(df_agriculture[df_agriculture['Country']==i]['Value'])

# %%
df_agriculture['']
# Out:
#        COU        Country  POL         Pollutant    VAR         Variable  \
# 33785  POL         Poland  GHG  Greenhouse gases  AGR_P  3 - Agriculture
# 33786  POL         Poland  GHG  Greenhouse gases  AGR_P  3 - Agriculture
# 33787  POL         Poland  GHG  Greenhouse gases  AGR_P  3 - Agriculture
# 33788  POL         Poland  GHG  Greenhouse gases  AGR_P  3 - Agriculture
# 33789  POL         Poland  GHG  Greenhouse gases  AGR_P  3 - Agriculture
# 33790  POL         Poland  GHG  Greenhouse gases  AGR_P  3 - Agriculture
# 33791  POL         Poland  GHG  Greenhouse gases  AGR_P  3 - Agriculture
# 33792  POL         Poland  GHG  Greenhouse gases  AGR_P  3 - Agriculture
# 33793  POL         Poland  GHG  Greenhouse gases  AGR_P  3 - Agriculture
# 33794  POL         Poland  GHG  Greenhouse gases  AGR_P  3 - Agriculture
# 33795  POL         Poland  GHG  Greenhouse gases  AGR_P  3 - Agriculture
# 33796  POL         Poland  GHG  Greenhouse gases  AGR_P  3 - Agriculture
# ...

# %%
kk =df_greenhouse_gas[df_greenhouse_gas["POL"] =="GHG"]

kkk= kk[kk["VAR"]=="TOTAL"]

# %%
kkk
# Out:
#         COU                        Country  POL         Pollutant    VAR  \
# 0       AUS                      Australia  GHG  Greenhouse gases  TOTAL
# 1       AUS                      Australia  GHG  Greenhouse gases  TOTAL
# 2       AUS                      Australia  GHG  Greenhouse gases  TOTAL
# 3       AUS                      Australia  GHG  Greenhouse gases  TOTAL
# 4       AUS                      Australia  GHG  Greenhouse gases  TOTAL
# 5       AUS                      Australia  GHG  Greenhouse gases  TOTAL
# 6       AUS                      Australia  GHG  Greenhouse gases  TOTAL
# 7       AUS                      Australia  GHG  Greenhouse gases  TOTAL
# 8       AUS                      Australia  GHG  Greenhouse gases  TOTAL
# 9       AUS                      Australia  GHG  Greenhouse gases  TOTAL
# 10      AUS                      Australia  GHG  Greenhouse gases  TOTAL
# 11      AUS                      Australia  GHG  Greenhouse gases  TOTAL
# ...

# %%
df_greenhouse_gas
# Out:
#        COU     Country  POL         Pollutant         VAR  \
# 0      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 1      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 2      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 3      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 4      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 5      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 6      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 7      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 8      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 9      AUS   Australia  GHG  Greenhouse gases       TOTAL
# 10     AUS   Australia  GHG  Greenhouse gases       TOTAL
# 11     AUS   Australia  GHG  Greenhouse gases       TOTAL
# 12     AUS   Australia  GHG  Greenhouse gases       TOTAL
# 13     AUS   Australia  GHG  Greenhouse gases       TOTAL
# 14     AUS   Australia  GHG  Greenhouse gases       TOTAL
# ...

# %% [markdown]
# # <center>STUDENT AT PARYS SACLAY 25 OCTOBER 2020</center>#
# # <center> Programming Project Document Similarity</center>#
# #  NAMES: PANONGBENE JEAN MOHAMED SAWADOGO #
# # Email: amet1900@gmail.com #
# # Github: https://github.com/Panongbene #

# %%
import nltk
import numpy as np
import pandas as pd
from copy import deepcopy
from random import shuffle
from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# # define extra parameter

# %%
# use this variable for the tokenize the text
tokenizer = nltk.RegexpTokenizer(r'\w+')

# name File Text
name_file_text = "tweets.txt"

# the threshold value
threshold_simmilarity = 0.05

# the number of permutation function
number_hash_function = 10

# the number of bande 
number_of_bande = 5

# the size of shingle
size_shingle = 5

# %matplotlib inline

# %% [markdown]
# # load data

# %%
# the list containing each line of the doc
array_data = list()

# open the file and build the list
file1 = open(name_file_text,"r")
for i in file1.readlines():
    array_data.append(i.split("\r\n")[0])
file1.close() 

# creation of a dataframe containing the text
data_frame_text_1 = pd.DataFrame(data=array_data, columns=['Text_line'])

# %% [markdown]
# # compute the execution time

# %%
#https://www.kaggle.com/tilii7/hyperparameter-grid-search-with-xgboost
def timer(start_time=None):
    """This function compute the execution time of algorithm"""
    
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        #print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

    return thour, tmin, round(tsec, 2)

# %% [markdown]
# # Define the Jaccard similarity

# %%
def jaccard_similarity(text_1, text_2):
    """This function take two list of word and return the jaccard similarity"""
    
    text_1_inter_text_2 = 0
    
    for i in text_1:
        if i in text_2:
            text_1_inter_text_2+=1
            
    return float(text_1_inter_text_2)/float(len(text_1)+len(text_2)-text_1_inter_text_2)

# %% [markdown]
# # Define the other version of Jaccard similarity

# %%
def jaccard_similarity_(kkkk, s1,s2):
    """Another version of jaccard similarity"""
    
    valeur = 0
    
    for kj in range(len(kkkk)):
        if(kkkk[kj][s1] == kkkk[kj][s2]):
            valeur+=1
    
    return valeur

# %% [markdown]
# # Preprocessing data

# %%
def preprocessing_doc(array_data):
    """We use this function for build a dictionary where the keys is the ids of document and the values is the 
    texts"""
    
    # define a dictionnary that the function will return 
    dictionnary_doc_1 = dict()
    
    #tokekenize the doc
    for i in range(len(array_data)):
        array_text_tokenize = tokenizer.tokenize(array_data[i].lower())
        text = ""
        for k in array_text_tokenize:
            text+=k
        
        dictionnary_doc_1[i]=text
        
    return dictionnary_doc_1

# %% [markdown]
# # Define the k shingling function

# %%
def k_shingling_caractere(dictionnary_doc, size_k):
    """This function take a dictionary where the keys are the ids of docs and the values 
    are the texts containing the essential words of the document. The second parameter is
    the length of shingling"""
    
    shingling = dict()
    
    key = 0
    for i in dictionnary_doc:
        kkkk = list()
        text = dictionnary_doc[i]
        
        if(len(text)>=size_k):
            j = 0;
            
            while(j+size_k < len(text)):
                kkk = ""
                for k in range(j, j+size_k):
                    kkk+=text[k]
                j+=1
                kkkk.append(kkk)
            
            kkk = ""
            for k in range(j, len(text)):
                kkk+=text[k]
            kkkk.append(kkk)
            
            shingling[key]=kkkk
            key+=1
        else:
            kkk = ""
            for k in range(len(text)):
                kkk+=text[k]
            kkkk.append(kkk)
            shingling[key]=kkkk
            key+=1
            
    
    # the dictionnary will contain all different k-shingle
    shingle_hash = list()
    
    # building the shingle_hash
    k = 0
    for i in shingling:
        for j in shingling[i]:
            if j not in shingle_hash:
                shingle_hash.append(j)
            
    return shingling, shingle_hash

# %% [markdown]
# # Build the min hashing matrix

# %%
def build_min_hashing_matrix(dictionnary_doc, shingle_hash, permutation_functions):
    """this function is used to build the signature matrix"""
    
    signature_matrix = dict()
 
    for k in range(len(permutation_functions)):
        value_row = list()

        #--------------------------------------------
        for i in dictionnary_doc:
            for j in permutation_functions[k]:
                if(j in dictionnary_doc[i]):
                    value_row.append(j)
                    break
        #--------------------------------------------            
        
        signature_matrix[k] = value_row
        
    return signature_matrix

# %% [markdown]
# # Build the similarity matrix

# %%
def build_similarity_matrix(signature_matrix):
    """This function take minhashing matrix and return the signature matrix"""
    
    similarity_matrix = dict()
    
    
    for i in range(len(signature_matrix[0])-1):
        
        array_tampon = list()
        
        for j in range(len(signature_matrix[0])):
            array_tampon.append(jaccard_similarity_(signature_matrix, i,j)/number_hash_function)
        
        similarity_matrix[i]=array_tampon
            
    
    return similarity_matrix

# %% [markdown]
# # hash bande function

# %%
def hash_bande(bande,hashage_function):
    """We use this function to hash a band"""
    
    hash_bande = list()
    
    for i in range(len(bande[0])):
        array_test = list()
        for j in range(len(bande)):
            array_test.append(bande[j][i])
        
        for k in hashage_function:
            if k in array_test:
                hash_bande.append(k)
                break
                
    return hash_bande

# %% [markdown]
# # Build the locality sensitive function

# %%
def locality_sensitive_hashing(signature_matrix,number_of_bande,shingle_hash):
    """This function constructs the function of Locality sensitive hashing"""
    
    bande_bucket = dict()
    size_bande = 0
        
    locality_sensitive_hashing_matrix = dict()
    
    # we create number_of_bande of permutation function
    hashage_function = dict()
    for i in range(number_of_bande):
        hashage_function[i] = deepcopy(shingle_hash)
        shuffle(hashage_function[i])     
    
    # it is necessary to choose a number_of_bande that divide the number of row of signature_matrix
    if(len(signature_matrix) % number_of_bande != 0):
        print(" number of bande is not a multiple of number of row signature matrix")
        return bande_bucket
    else:
        size_bande = len(signature_matrix)//number_of_bande
        

    for k in range(number_of_bande):
        
        bande_k = dict()
        
        for kj in range(size_bande):
            bande_k[kj] = signature_matrix[k*size_bande+kj]
        
        bande_bucket[k] = hash_bande(bande_k,hashage_function[k])
        
        
        
    for i in range(len(bande_bucket[0])):
        array_test = list()
        for j in range(len(bande_bucket[0])):
            kkp = 0
            for z in range(number_of_bande):
                if(bande_bucket[z][i] == bande_bucket[z][j]):
                    kkp+=1

            array_test.append(kkp/number_of_bande)
        
        locality_sensitive_hashing_matrix[i] = array_test
        
    return locality_sensitive_hashing_matrix

# %% [markdown]
# # Implementation tests

# %%
#dictionnary_doc = preprocessing_document(array_data)
dictionnary_doc_1 = preprocessing_doc(array_data)

# %%
for i in dictionnary_doc_1:
    print("id doc = ",i,"  doc = ",dictionnary_doc_1[i])
# Out:
# id doc =  0   doc =  stellargirliloooooooovvvvvveeemykindle2notthatthedxiscoolbutthe2isfantasticinitsownright
# id doc =  1   doc =  readingmykindle2loveitleechildsisgoodread
# id doc =  2   doc =  okfirstassesmentofthekindle2itfuckingrocks
# id doc =  3   doc =  kenburbaryyoullloveyourkindle2ivehadmineforafewmonthsandneverlookedbackthenewbigoneishugenoneedforremorse
# id doc =  4   doc =  mikefishfairenoughbutihavethekindle2andithinkitsperfect
# id doc =  5   doc =  richardebakernoitistoobigimquitehappywiththekindle2
# id doc =  6   doc =  fuckthiseconomyihateaigandtheirnonloangivenasses
# id doc =  7   doc =  jqueryismynewbestfriend
# id doc =  8   doc =  lovestwitter
# id doc =  9   doc =  howcanyounotloveobamahemakesjokesabouthimself
# id doc =  10   doc =  checkthisvideooutpresidentobamaatthewhitehousecorrespondentsdinnerhttpbitlyimxum
# id doc =  11   doc =  karoliifirmlybelievethatobamapelosihavezerodesiretobecivilitsacharadeandasloganbuttheywanttodestroyconservatism
# id doc =  12   doc =  housecorrespondentsdinnerwaslastnightwhoopibarbaraamp
# id doc =  13   doc =  watchinespnjusseenthisnewnikecommericalwithapuppetlebronshtwashilariouslmao
# id doc =  14   doc =  dearnikestopwiththeflywirethatshitisawasteofscienceanduglylovevincentx24x
# id doc =  15   doc =  lebronbestathleteofourgenerationifnotalltimebasketballrelatedidontwanttogetintointersportdebatesabout__12
# id doc =  16   doc =  iwastalkingtothisguylastnightandhewastellingmethatheisadiehardspursfanhealsotoldmethathehateslebronjames
# id doc =  17   doc =  ilovelebronhttpbitlypdhur
# id doc =  18   doc =  ludajuicelebronisabeastbutimstillcheering4theatiltheend
# id doc =  19   doc =  pmillzzlebronistheboss
# id doc =  20   doc =  sketchbuglebronisahometownherotomelolilovethelakersbutletsgocavslol
# id doc =  21   doc =  lebronandzydrunasaresuchanawesomeduo
# id doc =  22   doc =  wordwhizkidlebronisabeastnobodyinthenbacomesevenclose
# id doc =  23   doc =  downloadingappsformyiphonesomuchfunthereliterallyisanappforjustaboutanything
# id doc =  24   doc =  goodnewsjusthadacallfromthevisaofficesayingeverythingisfinewhatareliefiamsickofscamsouttherestealing
# id doc =  25   doc =  httptwurlnlepkr4bawesomecomebackfrombizviafredwilson
# id doc =  26   doc =  inmontrealforalongweekendoframp
# id doc =  27   doc =  boozallenhamiltonhasabadasshomegrownsocialcollaborationplatformwaycoolttiv
# id doc =  28   doc =  mluc09customerinnovationawardwinnerboozallenhamiltonhttppingfmc2hpp
# id doc =  29   doc =  sochi2icurrentusethenikond90andloveitbutnotasmuchasthecanon40d50dichosethed90forthevideofeaturemymistake
# id doc =  30   doc =  needsuggestionsforagoodirfilterformycanon40dgotsomeplsdm
# id doc =  31   doc =  surfitijustcheckedmygoogleformybusinessblipshowsupasthesecondentryhuhisthatagoodorbahttpblipfm6emhv
# id doc =  32   doc =  phyreman9googleisalwaysagoodplacetolookshouldvementionediworkedonthemustangwmydadkimblet
# id doc =  33   doc =  playedwithanandroidgooglephonetheslideoutscreenscaresmeiwouldbreakthatfuckersofaststillprefermyiphone
# id doc =  34   doc =  usplanningtoresumethemilitarytribunalsatguantanamobayonlythistimethoseontrialwillbeaigexecsandchryslerdebtholders
# id doc =  35   doc =  omgsoboredamp
# id doc =  36   doc =  imitchyandmiserable
# id doc =  37   doc =  sekseemessnoimnotitchyfornowmaybelaterlol
# id doc =  38   doc =  rtjessverrilovethenerdystanfordhumanbiologyvideosmakesmemissschoolhttpbitly13t7nr
# id doc =  39   doc =  spinuzzihasbeenabitcrazywithsteeplearningcurvebutlyxisreallygoodforlongdocsforanythingshorteritwouldbeinsane
# id doc =  40   doc =  imlisteningtopytbydannygokeylt
# id doc =  41   doc =  isgoingtosleepthenonabikeride
# id doc =  42   doc =  cantsleepmytoothisaching
# id doc =  43   doc =  blahblahblahsameoldsameoldnoplanstodaygoingbacktosleepiguess
# id doc =  44   doc =  gladididntdobaytobreakerstodayits1000freakingdegreesinsanfranciscowtf
# id doc =  45   doc =  isinsanfranciscoatbaytobreakers
# id doc =  46   doc =  justlandedatsanfrancisco
# id doc =  47   doc =  sanfranciscotodayanysuggestions
# id doc =  48   doc =  obamaadministrationmuststopbonusestoaigponzischemershttpbitly2cuig
# id doc =  49   doc =  startedtothinkthatcitiisinreallydeepsamp
# id doc =  50   doc =  shaunwoohatenonaig
# id doc =  51   doc =  yarnthingyouwillnotregretgoingtoseestartrekitwasawesome
# id doc =  52   doc =  onmywaytoseestartrektheesquire
# id doc =  53   doc =  goingtoseestartreksoonwithmydad
# id doc =  54   doc =  annoyingnewtrendontheinternetspeoplepickingapartmichaellewisandmalcolmgladwellnobodywantstoreadthat
# id doc =  55   doc =  billsimmonsinconversationwithmalcolmgladwellhttpbitlyj9o50
# id doc =  56   doc =  highlyrecommendhttptinyurlcomhowdavidbeatsgoliathbymalcolmgladwell
# id doc =  57   doc =  blinkbymalcolmgladwellamazingbookandthetippingpoint
# id doc =  58   doc =  malcolmgladwellmightbemynewmancrush
# id doc =  59   doc =  omgthecommercialsaloneonespnaregoingtodrivemenuts
# id doc =  60   doc =  robmalonplayingwithtwitterapisoundsfunmayneedtotakeaclassorfindanewfriendwholiketogenerateresultswithapicode
# id doc =  61   doc =  playingwithcurlandthetwitterapi
# id doc =  62   doc =  hellotwitterapi
# id doc =  63   doc =  playingwithjavaandthetwitterapi
# id doc =  64   doc =  morind45becausethetwitterapiisslowandmostclientsarentgood
# id doc =  65   doc =  yahooanswerscanbeabuttsometimes
# id doc =  66   doc =  isscrapbookingwithnicd
# id doc =  67   doc =  rtmashablefivethingswolframalphadoesbetterandvastlydifferentthangooglehttpbitly6nsnr
# id doc =  68   doc =  justchangedmydefaultpictoanikebasketballcausebballisawesome
# id doc =  69   doc =  nikeownsnbaplayoffsadswlebronkobecarmelohttpowly7uiyadidasbillupshowardmarketingbranding
# id doc =  70   doc =  nexttimeillcallmyselfnike
# id doc =  71   doc =  newblogpostnikesbdunklowpremiumwhitegumhttptrimlott
# id doc =  72   doc =  rtsmartchickpdxwasjusttoldthatnikelayoffsstartedtoday
# id doc =  73   doc =  backwheniworkedfornikewehadonefavwordjustdoit
# id doc =  74   doc =  bythewayimtotallyinspiredbythisfreakynikecommercialhttpsnurlcomicgj9
# id doc =  75   doc =  givingwekaanappengineinterfaceusingthebirdstrikedatafortheteststhelogoisagiven
# id doc =  76   doc =  brandnewcanoneos50d15mpdslrcameracanon1785mmislenswebtechnologythreadbrandnewcanoneos5httpumavrevcom5a3t
# id doc =  77   doc =  classthe50dissupposedtocometoday
# id doc =  78   doc =  needssomeonetoexplainlambdacalculustohim
# id doc =  79   doc =  tookthegraduatefieldexamforcomputersciencetodaynothingmakesyoufeellikemoreofanidiotthanlambdacalculus
# id doc =  80   doc =  shoutoutstoalleastpaloaltoforbeinginthebuildinkarizmakaze50calgtaalsothankstoprofitsofdoomuniversalhempzcracka
# id doc =  81   doc =  legalgeekeryyeahhhhhhhhhiwouldntreallyhavelivedineastpaloaltoificouldhaveavoideditiguessitsonlyforthesummer
# id doc =  82   doc =  accannisedog1203greatstanfordcoursethanksformakingitavailabletothepublicreallyhelpfulandinformativeforstartingoff
# id doc =  83   doc =  nvidianamesstanfordsbilldallychiefscientistvpofresearchhttpbitlyfvvg9
# id doc =  84   doc =  newblogpostharvardversusstanfordwhowinshttpbitlymcoco
# id doc =  85   doc =  worktil6pmletsgolakers
# id doc =  86   doc =  damnyounorthkoreahttpbitlyktmeq
# id doc =  87   doc =  canwejustgoaheadandblownorthkoreaoffthemapalready
# id doc =  88   doc =  northkoreapleaseceasethisdouchebaggerychinadoesntevenlikeyouanymorehttpbitlynehsl
# id doc =  89   doc =  whythehellispelosiinfreakinchinaandonwhosedime
# id doc =  90   doc =  areyouburningmorecashthanchryslerandgmstopthefinancialtsunamiwherebailoutmeanstakingahandout
# id doc =  91   doc =  insectshaveinfectedmyspinachplant
# id doc =  92   doc =  wishicouldcatcheverymosquitointheworldnburnemslowlytheybeenbitintheshitouttame2daymosquitosaretheassholesofinsects
# id doc =  93   doc =  justgotbackfromchurchanditotallyhateinsects
# id doc =  94   doc =  justgotmcdonaldsgoddamthoseeggsmakemesickoyeahlakerupdategolakersnotmuchofanupdatewellitstruesosuckit
# id doc =  95   doc =  omggiohhdeewantmcdonaldsdamniwonderifitsopenlol
# id doc =  96   doc =  historyexamstudyingugh
# id doc =  97   doc =  ihaterevisionitssoboringiamtotallyunpreparedformyexamtomorrowthingsarenotlookinggood
# id doc =  98   doc =  higherphysicsexamtommorownotlookinforwardtoitmuch
# id doc =  99   doc =  itsabankholidayyetimonlyoutofworknowexamseasonsucks
# id doc =  100   doc =  cheneyandbusharetherealculpritshttpfwixcomarticle939496
# id doc =  101   doc =  lifesabitchandsoisdickcheneyp2biparttlottcothhrsgopdnchttpisgddjyq
# id doc =  102   doc =  dickcheneysdishonestspeechabouttortureterrorandobamafredkaplanslatehttpisgddihg
# id doc =  103   doc =  therepublicanpartyisabunchofantiabortionzealotswhocouldntdrawfliestoadumpnealboortzjustnowontheradio
# id doc =  104   doc =  istwittersconnectionsapibrokensometweetsdidntmakeittotwitter
# id doc =  105   doc =  isrslyhatethestupidtwitterapitimeoutthingsooooannoying
# id doc =  106   doc =  psychemediaireallylikedkswedbergslearningjquerybookhttpbitlypg0ltisworthalooktoo
# id doc =  107   doc =  jqueryui16bookreviewhttpcfbloggersorgc30631
# id doc =  108   doc =  veryinterestingadfromadobebygoodbysilversteinamp
# id doc =  109   doc =  goodbysilversteinagencynewsitehttpwwwgoodbysilversteincomgreat
# id doc =  110   doc =  rtdesignplaygoodbysilversteinsnewsitehttpwwwgoodbysilversteincomienjoyitnicefind
# id doc =  111   doc =  theeveramazingpsyopandgoodbysilversteinamp
# id doc =  112   doc =  toptenmostwatchedonviralvideochartlovethenikemostvaluablepuppetscampaignfromwiedenamp
# id doc =  113   doc =  zomgihaveag2
# id doc =  114   doc =  oksolotsofbuzzfromio2009buthowluckyaretheyafreeg2httpisgdhyzl
# id doc =  115   doc =  justgotafreeg2androidatgoogleio
# id doc =  116   doc =  guessillberetiringmyg1andstartusingmydeveloperg2wootgoogleio
# id doc =  117   doc =  atgwtfiresidechatgoogleio
# id doc =  118   doc =  iamhappyforphilipbeingatgoogleiotoday
# id doc =  119   doc =  lakersplayedgreatcannotwaitforthursdaynightlakersvs
# id doc =  120   doc =  hitheredoesanyonehaveagreatsourceforadviceonviralmarketinghttplinkgsytz8
# id doc =  121   doc =  juddapatowcreatesfakesitcomonnbccomtomarkethisnewmovieviralmarketingatitsbesthttpisgdk0yk
# id doc =  122   doc =  heresacasestudyonhowtouseviralmarketingtoaddover10000peopletoyourlisthttpsniprcomi50oz
# id doc =  123   doc =  viralmarketingfailthisaciapillsbrandoughtagetshutdownforhackingintopeoplesmessengersiget56msgsinadayarrrgh
# id doc =  124   doc =  watchingnightatthemuseumlmao
# id doc =  125   doc =  ilovednightatthemuseum
# id doc =  126   doc =  goingtoseethenewnightatthemuseummoviewithmyfamilyohboyathreeyearoldinthemoviesfuin
# id doc =  127   doc =  justgotbackfromthemovieswenttoseethenewnightatthemuseumwithrachelitwasgood
# id doc =  128   doc =  justsawthenewnightatthemuseummovieitwasokaylol710
# id doc =  129   doc =  goingtoseenightatthemuseum2withtallboy
# id doc =  130   doc =  shannyodayiwilltakeyouonadatetoseenightatthemuseum2wheneveryouwantitlookssoooooogood
# id doc =  131   doc =  nowatchingthenightatthemuseumgettingreallygood
# id doc =  132   doc =  nightatthemuseumwolverineandjunkfoodperfectmonday
# id doc =  133   doc =  sawnightatthemuseum2lastnightprettycrazymoviebutthecastwasawesomesoitwaswellworthitrobinwilliamsforever
# id doc =  134   doc =  isawnightatthemuseumbattleoftheswithsoniantodayitwasokayyourtypicalkidsbenstillermovie
# id doc =  135   doc =  takingkatietoseenightatthemuseumshepickedit
# id doc =  136   doc =  nightatthemuseumtoniteinsteadofupohwellthat4yroldbetterenjoyitlol
# id doc =  137   doc =  gmsaysexpectsannouncmentonsaleofhummersoonreuterswdsugmsaysexpectsannouncmentonsaleofhummerhttpbitly4e1fv
# id doc =  138   doc =  itsunfortunatethatafterthestimulusplanwasputinplacetwicetohelpgmonthebackoftheamericanpeoplehasledtotheinevitable
# id doc =  139   doc =  tellmeagainwhywearegivingmoretogmweshouldusethatforalltheprogramsthatsupporttheunemployed
# id doc =  140   doc =  jdreissohyesbutifgmdiesitwillonlybeworthmoreboohahaha
# id doc =  141   doc =  timewarnercableisdownagain3rdtimesincememorialdaybummer
# id doc =  142   doc =  iwouldratherpayreasonableyearlytaxesforfreefastinternetthangetgougedbytimewarnerforaslowconnection
# id doc =  143   doc =  nooooooomydvrjustdiedandiwasonlyhalfwaythroughtheeapresserhateyoutimewarner
# id doc =  144   doc =  fcktimewarnercableyoufckingsuckballsihavea700hdtvamp
# id doc =  145   doc =  timewarnerhastheworsecustomerserviceeveriwillneverusethemagain
# id doc =  146   doc =  timewarneristhedevilworstpossibletimefortheinternettogoout
# id doc =  147   doc =  fucknointernetdamntimewarner
# id doc =  148   doc =  timewarnerreallypickstheworsttimetonotworkalliwanttodoisgettomtvcomsoicanwatchthehillswtfffff
# id doc =  149   doc =  ihatetimewarnersoooowishihadvioscantwatchthefrickenmetsgamewobufferingifeellikeimwatchingfreeinternetporn
# id doc =  150   doc =  ahhgotridofstupidtimewarnertodayamp
# id doc =  151   doc =  timewarnershdlineupiscrap
# id doc =  152   doc =  isbeingfuckedbytimewarnercabledidntknowmodemscouldexplodeandsusanboylesuckstoo
# id doc =  153   doc =  timewarnercablepullstheplugonthegirlfriendexperiencewwwtinyurlcomm595fk
# id doc =  154   doc =  timewarnercablesloganwherecallingitadayat2pmhappens
# id doc =  155   doc =  rocawearheadstochinabuilding300storeshttptinyurlcomnofet3
# id doc =  156   doc =  climatefocusturnstobeijingtheunitednationstheusandeuropeangovernmentshavecalledonchinatocoohttptinyurlcomlto92n
# id doc =  157   doc =  myfoxdcbarriestudentsbackfromtriptochinaasilverspringhighschoolsclasstriptochinahasenhttptinyurlcomnlhqba
# id doc =  158   doc =  threechinaaerospacegiantsdeveloptianjinbinhainewarea229byuaninvestedhttpbitlymmidv
# id doc =  159   doc =  httpxigs04fogmceochinawillcontinuetobekeypartner
# id doc =  160   doc =  rtlatimesautosisnowthetimetobuyagmcarhttpbitlynrzlu
# id doc =  161   doc =  recoveringfromsurgerywishingjulesrennerwashere
# id doc =  162   doc =  mywriststillhurtsihavetogetitlookedatihatethedrdentistscaryplacestimetowatcheagleeyeifyouwanttojointxt
# id doc =  163   doc =  dentisttomorrowhavetobrushwellinthemorninglikeimakemyhairallnicebeforeigetitcutwhy
# id doc =  164   doc =  thedentistlieduwontfeelanydiscomortprobwontevenneedpainpillsmanutwippinthisshithurthowmanypillscanitake
# id doc =  165   doc =  kirstiealleymydentistisgreatbutshesexpensive
# id doc =  166   doc =  kirstiealleypetdentisthttpwwwfunnyvillecomfvpicturesdogdenturesshtml
# id doc =  167   doc =  isstudingmath
# id doc =  168   doc =  mydentistwaswrongwrong
# id doc =  169   doc =  goingtothedentistlater
# id doc =  170   doc =  sonhasmelookingatcarsonlineihatecarshoppingwouldrathergotothedentistanyonewithagoodcaratagoodpricetosell
# id doc =  171   doc =  ncaabaseballsuperregionalramsclubhttpbitlyro7nx
# id doc =  172   doc =  juststartedplayingmajorleaguebaseball2k9httpraptrcomh3llgwar
# id doc =  173   doc =  cardinalsbaseballadvancetosuperregionalsfacecsfullertonfriday
# id doc =  174   doc =  sonycouponcodeexpiressoonhttpwwwcoupondorkcomr1796
# id doc =  175   doc =  waitinginlineatsafeway
# id doc =  176   doc =  lukeandigotstoppedwalkingoutofsafewayandaskedtoemptyourpocketsandliftourshirtshowjackedupisthat
# id doc =  177   doc =  didnotrealizethereisagymabovesafeway
# id doc =  178   doc =  xphile1908ihavethreewordsforyousafewaydotcom
# id doc =  179   doc =  safewayisveryrocknrolltonight
# id doc =  180   doc =  bouttohitsafewayigottaeat
# id doc =  181   doc =  jakesgoingtosafeway
# id doc =  182   doc =  foundasafewaypickingupafewstaples
# id doc =  183   doc =  safewaysupermarketingviamobilecouponshttpbitlyonh7w
# id doc =  184   doc =  thesafewaybathroomstillsmellslikeass
# id doc =  185   doc =  atsafewayonelkhorntheymoveliketheyredead
# id doc =  186   doc =  yournormalweightandhowtogettherenormaleatingbloghttpbitlyzet8o
# id doc =  187   doc =  iseatingandwatchingmovies
# id doc =  188   doc =  eatingsashimi
# id doc =  189   doc =  iseatinghomemadeyema
# id doc =  190   doc =  eatingcake
# id doc =  191   doc =  ilovedwighthowardsvitaminwatercommercialnowiwishhewaswithnikeandnotadidaslol
# id doc =  192   doc =  foundnothingatnikefactoryofftobananarepublicoutlethttpmylocme2zic
# id doc =  193   doc =  iphonemaygetradiotaggingandnikerecentlyreleaseditunesversion82suggeststhatvoiceoverfunctionalhttptinyurlcomoq5ctc
# id doc =  194   doc =  islovinhisnikealreadyandthatsonlyfromrunningonthespotinhisbedroom
# id doc =  195   doc =  launchedhttpimgsearchnetimgsearchajaxjquerywebapp
# id doc =  196   doc =  matthewcyanifinallygotaroundtousingjquerytomakemybiocollapseyayforslideanimations
# id doc =  197   doc =  rtjquerytheultimatejquerylisthttpjquerylistcom
# id doc =  198   doc =  ijustextractedandopensourcedajquerypluginfromstormweighttohighlighttextwitharegularexpressionhttpbitlyybjkb
# id doc =  199   doc =  anna_debenhamwhatwasthephpjqueryhack
# id doc =  200   doc =  jquerycheatsheethttpwwwjavascripttoolboxcomjquerycheatsheet
# id doc =  201   doc =  beginningjavascriptandcssdevelopmentwithjqueryjavascriptcssjqueryhttpbitlyto3e5
# id doc =  202   doc =  pdubyadrightlolwellgetthereihavehighexpectationswarrenbuffetstyle
# id doc =  203   doc =  rtblknprecious1rtgreatdbroossomeonessittingintheshadetodaybecausesomeoneplantedatreealongtimeagowarrenbuffet
# id doc =  204   doc =  warrenbuffetontheeconomyhttppingfmlau0p
# id doc =  205   doc =  warrenbuffetbecameforatimetherichestmanintheunitedstatesnotbyworkingbutinvestingin1bigideawhichleadtothefortune
# id doc =  206   doc =  accordingtothecreateaschoolnotredamewillhave7receiversinncaa10at84orhigherratingsweet
# id doc =  207   doc =  allstarbasketballclassictuesdayfeaturestoptalentchattanoogasnotredamehighschoolwillplayhosthttpbitlyqltja
# id doc =  208   doc =  blondebroaditsdefinitelyunderwarrantyamp
# id doc =  209   doc =  rtlookavailableamazonkindle2amp
# id doc =  210   doc =  timewarnerroadrunnercustomersupporthereabsolutelyblowsihatenothavingotherhighspeednetoptionsimreadytogonuclear
# id doc =  211   doc =  timewarnercablephonerepsrdumberthannailsughcablewasworking10minsagonowitsnotwtf
# id doc =  212   doc =  siratomofboneswetriedbuttimewarnerwasntbeingnicesowerecordedtoday
# id doc =  213   doc =  omgtimewarnerfedupmyinternetinstallinsteadoftodayitsnownextsaturdayanotherweekwointernetamp
# id doc =  214   doc =  wthihaveneverseenalinethisloooongattimewarnerbeforeugh
# id doc =  215   doc =  impatientlyawaitingthearrivalofthetimewarnerguyitswaytooprettytobeinsideallafternoon
# id doc =  216   doc =  manaccostsrogerfedererduringfrenchopenhttpffim3hcpt
# id doc =  217   doc =  naivebayesusingemfortextclassificationreallyfrustrating
# id doc =  218   doc =  wewenttostanforduniversitytodaygotatourmademewanttogobacktocollegeitsalsodecidedallofourkidswillgothere
# id doc =  219   doc =  investigationpendingondeathofstanfordcsprofgooglementorrajeevmotwanihttpbitlylwourtiptechmeme
# id doc =  220   doc =  imgoingtobeditwasasuccessfulweekendstanfordhereicome
# id doc =  221   doc =  karrisfoxyifyourebeingharassedbycallsaboutyourcarwarrantychangingyournumberwontfixthattheycalleverynumberdbags
# id doc =  222   doc =  justblockedunitedbloodservicesusinggooglevoicetheycallmorethanthosecarwarrantyguys
# id doc =  223   doc =  atamp
# id doc =  224   doc =  broskiiiohsnapyouworkatatamp
# id doc =  225   doc =  mbjthegreatireallydontwantatamp
# id doc =  226   doc =  isaywejustcutoutthesmalltalkatamp
# id doc =  227   doc =  pissedaboutatamp
# id doc =  228   doc =  safari4isfastevenonmyshittyatamp
# id doc =  229   doc =  imswhatisatamp
# id doc =  230   doc =  springsingfienddvyerssethdaggettjlshackatamp
# id doc =  231   doc =  mmbarnhillyaygladyougotthephonestilldamnyouatamp
# id doc =  232   doc =  googlewavedevelopersandboxaccountrequesthttpbitly2nylc
# id doc =  233   doc =  talkischeapbingthatillstickwithgooglehttpbitlyxc3c8
# id doc =  234   doc =  defsoundswtfisthepointofdeletingtweetsiftheycanstillbefoundinsummizeandsearchestwitterpleasefixthatthanksandbye
# id doc =  235   doc =  mattcuttshavegoogleprofilesstoppedshowingupinsearchescantseethemanymore
# id doc =  236   doc =  arunbasillalilovegoogletranslatortoodgooddaymate
# id doc =  237   doc =  readingonmynewkindle2
# id doc =  238   doc =  mykindle2cameandiloveit
# id doc =  239   doc =  lovingmynewkindle2namedherkendraincaseuwerewonderingthecookbookisthetoolcuzittellsuallthetricksbestgiftevr
# id doc =  240   doc =  therealaigscandalhttpbitlyb82px
# id doc =  241   doc =  anytwittertoaprsappsyet
# id doc =  242   doc =  45prosyoushouldbefollowingontwitterhttpisgdsmbz
# id doc =  243   doc =  obamaisquiteagoodcomediancheckouthisdinnerspeechoncnnveryfunnyjokes
# id doc =  244   doc =  barackobamashowshisfunnysidegt
# id doc =  245   doc =  ilikethisguybarackobamashowshisfunnysidegt
# id doc =  246   doc =  obamasspeechwasprettyawesomelastnighthttpbitlyimxum
# id doc =  247   doc =  readingbillclintonfailobamawinhttptinyurlcompcyxj7
# id doc =  248   doc =  obamamorepopularthanusamongarabssurveypresidentbarackobamaspopularityinleadingarabcountrieshttptinyurlcomprlvqu
# id doc =  249   doc =  obamasgotjokeshahajustgottowatchabitofhisafterdinnerspeechfromlastnightiminlovewithmrpresident
# id doc =  250   doc =  lebronjamesgotinacaraccidentiguessjusthearditoneveningnewswowicantbelieveitwillhebeokhttptwtadcom69750
# id doc =  251   doc =  isitmeoristhisthebesttheplayoffshavebeeninyearsohyealebronandmelointhefinals
# id doc =  252   doc =  khalid0456nolebronisthebest
# id doc =  253   doc =  the_real_usherlebroniscoolilikehispersonalityhehasgoodcharacter
# id doc =  254   doc =  watchinglebronhighlightsdamnthatniggasgood
# id doc =  255   doc =  lou911lebronismurderingshit
# id doc =  256   doc =  uscsports21lebronisamonstaandheisonly24smhtheworldaintready
# id doc =  257   doc =  cthagodwhenlebronisdoneinthenbahewillprobablybegreaterthankobelikeusaidkobeisgoodbuttherealotofgoodplayers
# id doc =  258   doc =  kobeisgoodbtlebronhasmyvote
# id doc =  259   doc =  kobeisthebestintheworldnotlebron
# id doc =  260   doc =  asherrothworldcup2010accessdamnthatsagoodlook
# id doc =  261   doc =  justboughtmyticketsforthe2010fifaworldcupinsouthafricaitsgoingtobeagreatsummerhttpbitly9gezi
# id doc =  262   doc =  sharedisruptionfredwilsonsslidesforhistalkatgooglehqhttpbitlybo8pg
# id doc =  263   doc =  ihavetogotoboozallenhamiltonfora2hrmeetingbutthenigettogohome
# id doc =  264   doc =  thegreatindiantamashatrulywillunfoldfrommay16theresultdayforindiangeneralelection
# id doc =  265   doc =  crlaneihavethekindle2iveseenpicturesofthedxbuthaventseenitinpersonilovemykindleimoniteveryday
# id doc =  266   doc =  criticalpathsuchanawesomeideathecontinuallearningprogramwithakindle2httpbitly1zlff
# id doc =  267   doc =  okdonothingjustthinkingabout40d
# id doc =  268   doc =  faithbabywearoooohwhatmodelareyougettingihavethe40dandloveloveloveloveit
# id doc =  269   doc =  thetimesofindiathewonderthatisindiaselectionhttpbitlyp7u1h
# id doc =  270   doc =  httpisgdarujgoodvideofromgoogleonusingsearchoptions
# id doc =  271   doc =  ambcharlesfieldlolahmyskinisitchydamnlawnmowing
# id doc =  272   doc =  itchybackdontyahateit
# id doc =  273   doc =  stanfordcharityfashionshowatopdrawhttpcligsnenuah
# id doc =  274   doc =  stanforduniversitysfacebookprofileisoneofthemostpopularofficialuniversitypageshttptinyurlcomp5b3fl
# id doc =  275   doc =  lyxiscool
# id doc =  276   doc =  sooodissapointedtheysentdannygokeyhomeyoustillrockdannymyhometownheroyeahmilrockee
# id doc =  277   doc =  rtpassionmodelamericanidolfashionadamlamberttonesdowndannygokeycutehttpcligs7jwshv
# id doc =  278   doc =  dannygokeyiloveyoudannygokey
# id doc =  279   doc =  rtjustindaveyrttweetmemegmonstarnowinstantlysendsaccidentlocationcoordinatesto911gpsobsessedhttpbitly16szl1
# id doc =  280   doc =  sotiredididntsleepwellatalllastnight
# id doc =  281   doc =  boardingplaneforsanfranciscoin1hour
# id doc =  282   doc =  bonjoursanfranciscomybackhurtsfromlastnight
# id doc =  283   doc =  breakersinsanfranciscocahttplooptus4v88bwt
# id doc =  284   doc =  headingtosanfrancisco
# id doc =  285   doc =  withmybestgirlforafewmorehoursinsanfranciscommmmmfamilyiswonderful
# id doc =  286   doc =  fupbigorgohomeaig
# id doc =  287   doc =  wenttoseethestartrekmovielastnightverysatisfying
# id doc =  288   doc =  icantwaitgoingtoseestartrektonight
# id doc =  289   doc =  startrekwasasgoodaseveryonesaid
# id doc =  290   doc =  amlovingnewmalcolmgladwellbookoutliers
# id doc =  291   doc =  ihighlyrecommendmalcolmgladwellsthetippingpointmynextaudiobookwillprobablybeoneofhisaswell
# id doc =  292   doc =  malcolmgladwellisageniusattrickingpeopleintonotrealizinghesafuckingidiot
# id doc =  293   doc =  sportsguy33heynooffensebutmalcolmgladwellisapreteniousannoyingcuntandhebringsyoudowncantreadhisshit
# id doc =  294   doc =  rtclashmorehttpbitlysoyv7greatarticlebymalcolmgladwell
# id doc =  295   doc =  iseriouslyunderestimatedmalcolmgladwelliwanttomeetthisdude
# id doc =  296   doc =  ihatecomcastrightnoweverythingisdowncableinternetamp
# id doc =  297   doc =  comcastsucks
# id doc =  298   doc =  thedayineverhavetodealwithcomcastagainwillrankasoneofthebestdaysofmylife
# id doc =  299   doc =  dommmdidcomcastfailagain
# id doc =  300   doc =  howdoyouusethetwitterapihttpbitly4vbhh
# id doc =  301   doc =  cursesthetwitterapilimit
# id doc =  302   doc =  nowicanseewhydavewinerscreamsaboutlackoftwitterapiitslimitationsandaccessthrottles
# id doc =  303   doc =  testingtwitterapi
# id doc =  304   doc =  argtwitterapiismakingmecrazy
# id doc =  305   doc =  testingtwitterapiremoteupdate
# id doc =  306   doc =  imreallylovingthenewsearchsitewolframalphamakesgoogleseemsoquainthttpwww72wolframalphacom
# id doc =  307   doc =  wolframalphasucksevenforresearcherstheinformationprovidedislessthanyoucangetfromgoogleorwikipediatotallyuseless
# id doc =  308   doc =  offtothenikefactory
# id doc =  309   doc =  newnikemuppetcommercialsareprettycutewhydowelivetogetheragain
# id doc =  310   doc =  newblogpostnikezoomlebronsoldier3iiiwhiteblacktealhttpbitlyrouus
# id doc =  311   doc =  newblogpostniketrainer1httpbitly394bp
# id doc =  312   doc =  fraggle312ohthoseareawesomeisowishtheywerentownedbynike
# id doc =  313   doc =  tonyhawkhttptwitpiccom5c7ujawesomeseeingtheshowfridayattheshorelineamphitheatreneverseenninbeforecantwait
# id doc =  314   doc =  arhhitswekabugandispentalmosttwohourstofindthatoutcrappyme
# id doc =  315   doc =  mitzsheybudnpidosolovemy50dalthoughidlovea5dmkiimore
# id doc =  316   doc =  jonduenasrobynlynjustgotusa50dfortheofficed
# id doc =  317   doc =  justpickedupmynewcanon50ditsbeautifulprepareforsomeseriouslyawesomephotography
# id doc =  318   doc =  justgotmynewtoycanon50dloveloveloveit
# id doc =  319   doc =  learningaboutlambdacalculus
# id doc =  320   doc =  jobssittercityhelpwithtakingcareofsickchildeastpaloaltocahttptinyurlcomqwrr2m
# id doc =  321   doc =  immovingtoeastpaloalto
# id doc =  322   doc =  atebitsijustfinishedwatchingyourstanfordiphoneclasssessionireallyappreciateityourock
# id doc =  323   doc =  jktweethijustsawyourstanfordtalkandreallylikedyouradvicejustsayinghifromsingaporeyesthevideosdogetaround
# id doc =  324   doc =  mbaadmissionstipsstanfordgsbdeadlinesandessaytopics20092010httptinyurlcompet4fd
# id doc =  325   doc =  ethicsandnonprofitshttpbitlyqsxrpstanfordsocialentrepreneurship
# id doc =  326   doc =  lakerstonightletsgo
# id doc =  327   doc =  willthelakerskickthenuggetsasstonight
# id doc =  328   doc =  ooooooohnorthkoreaisintroubleeeeehttpbitly19epah
# id doc =  329   doc =  wattheheckisnorthkoreadoingtheyjustconductedpowerfulnucleartestsfollowthelinkhttpwwwmsnbcmsncomid30921379
# id doc =  330   doc =  listeningtoobamafrigginnorthkorea
# id doc =  331   doc =  ijustrealizedwethreemonkeysinthewhiteobamabidenpelosisarahpalin2012
# id doc =  332   doc =  foxnewspelosishouldstayinchinaandnevercomeback
# id doc =  333   doc =  nancypelosigavetheworstcommencementspeechiveeverheardyesimstillbitteraboutthis
# id doc =  334   doc =  ughtheamountoftimesthesestupidinsectshavebittenmegrr
# id doc =  335   doc =  prettiestinsectseverpinkkatydidshttpbitly2upw2p
# id doc =  336   doc =  justgotbarragedbyahordeofinsectshungryformykitchenlightsoscary
# id doc =  337   doc =  justhadmcdonaldsfordinnerditwasgooooodbigmacmeal
# id doc =  338   doc =  ahhyeslolimatellmyhubbytogogetmesummcdonalds
# id doc =  339   doc =  stoppedtohavelunchatmcdonaldschickennuggetssssyummmmmy
# id doc =  340   doc =  couldgoforalotofmcdonaldsimeanalot
# id doc =  341   doc =  myexamwentgoodhelloleonieyourprayersworked
# id doc =  342   doc =  onlyoneexamleftandiamsohappyforitd
# id doc =  343   doc =  mathreviewimgoingtofailtheexam
# id doc =  344   doc =  colinpowellrockedyesterdayoncbscheneyneedstoshutthehellupandgohomepowellisamanofhonorandservedourcountryproudly
# id doc =  345   doc =  obviouslynotsidingwithcheneyherehttpbitly19j2d
# id doc =  346   doc =  absolutelyhilariousfrommashablehttpbitlybccwt
# id doc =  347   doc =  mashableineverdidthankyouforincludingmeinyourtop100twitterauthorsyourockamp
# id doc =  348   doc =  learningjquery13bookreviewhttpcfbloggersorgc30629
# id doc =  349   doc =  rtshropawesomejqueryreferencebookforcodahttpwwwmacpeepscomcodawebdesign
# id doc =  350   doc =  ivebeensendingemailslikecrazytodaytomycontactsdoesanyonehaveacontactatgoodbysilversteinidlovetospeaktothem
# id doc =  351   doc =  adobecs4commercialbygoodbysilversteinhttpbitly1aikhf
# id doc =  352   doc =  goodbysilversteinsnewsitehttpwwwgoodbysilversteincomienjoyit
# id doc =  353   doc =  woweveryoneatthegoogleioconferencegotfreeg2swithamonthofunlimitedservice
# id doc =  354   doc =  vkerkezdoodigotafreegoogleandroidphoneattheioconferencetheg2
# id doc =  355   doc =  orlitheg2isamazingbtwahugeimprovementovertheg1
# id doc =  356   doc =  html5demoslotsofgreatstufftocomeyesimexcitedhttphtmlfiveappspotcomio2009googleio
# id doc =  357   doc =  googleiohttptwitpiccom62shiyayhappyplaceplaceplaceilovegoogle
# id doc =  358   doc =  googleioo3dbringing3dgraphicstothebrowserverynicetbhfunfun
# id doc =  359   doc =  awesomeviralmarketingforfunnypeoplehttpwwwnbccomyoteach
# id doc =  360   doc =  watchingaprogrammeaboutthelifeofhitleritsonlyenhancingmygeekinessofhistory
# id doc =  361   doc =  sawnightatthemuseumoutofsheerdesperationwhoisfundingthesemovies
# id doc =  362   doc =  nightatthemuseum2prettyfurkingood
# id doc =  363   doc =  watchingnightatthemuseumgiggling
# id doc =  364   doc =  pambeeslyjennajennaiwenttoseenightatthemuseum2todayandiwassosurprisedtoseethreecastmembersfromtheoffice
# id doc =  365   doc =  abouttowatchnightatthemuseumwithryanandstacy
# id doc =  366   doc =  gettingreadytogowatchnightatthemuseum2dumdumyougivemegumgum
# id doc =  367   doc =  backfromseeingstartrekandnightatthemuseumstartrekwasamazingbutnightatthemuseumwas
# id doc =  368   doc =  justwatchednightatthemuseum2sostinkincute
# id doc =  369   doc =  sonightatthemuseum2wasawesomemuchbetterthanpart1nextweekendwellseeup
# id doc =  370   doc =  ithinkimayhaveanewfavoriterestaurantonourwaytoseenightatthemuseum2
# id doc =  371   doc =  upwassoldoutsoimseeingnightatthemuseum2im__yearsold
# id doc =  372   doc =  sawthenewnightatthemuseumandiloveditnextistogoseeupin3d
# id doc =  373   doc =  itisashameaboutgmwhatiftheyareforcedtomakeonlycarsthewhitehousethinkswillsellwhatdoyouthink
# id doc =  374   doc =  asumayhavenoticednottoohappyaboutthegmsituationnoraiglehmanetal
# id doc =  375   doc =  obamanationalizationofgmtobeshorttermaphttptinyurlcommd347r
# id doc =  376   doc =  pittstockgmgoodriddancesadthough
# id doc =  377   doc =  iwillneverbuyagovernmentmotorsvehicleuntiljustrecentlyidrovegmcarssince1988wheniboughtahttptinyurlcomlulsw8
# id doc =  378   doc =  havingtheoldcocacolaguyonthegmboardisstupidhashecktcotala
# id doc =  379   doc =  rantsandravestheworstthingaboutgmconcordpleasanthillmartinezisthefuckinguawhttpbuzzupcom4ueb
# id doc =  380   doc =  giveamanafishufeedhimforthedayteachhimtofishufeedhimforlifebuyhimgmandufkhimoverforgood
# id doc =  381   doc =  themoreihearaboutthisgmthingthemoreangryigetbillionswastedmorebullshitallforsomethinglike40kemployeesandallthe
# id doc =  382   doc =  quanttraderiownagmcaranditisjunkasfarasqualitycomparedtoahonda
# id doc =  383   doc =  saddaybankruptgm
# id doc =  384   doc =  isupsetaboutthewholegmthinglifeasiknowitissoscrewedup
# id doc =  385   doc =  whoeverisrunningtimewarnerneedstoberepeatedlyrapedbyarhinosotheyunderstandtheconsequencesofputtingoutshittycablesvcs
# id doc =  386   doc =  timewarnerceohintsatonlinefeesformagazinesapreadfrommountainviewunitedstatesviews16209httpbitlyudfch
# id doc =  387   doc =  wftbjoiningabitlatemyconnectionwasdownbootimewarner
# id doc =  388   doc =  coxortimewarnercoxischeaperandgetsabondslreportstwismoreexpensiveandgetsac
# id doc =  389   doc =  iamfuriouswithtimewarnerandtheirphonepromotions
# id doc =  390   doc =  justgothomefromchickfilawiththeboysdamnmyinternetsdownstupidtimewarner
# id doc =  391   doc =  couldtimewarnercablesuckmoreno
# id doc =  392   doc =  pissedattimewarnerforcausinmetohaveslowinternetproblems
# id doc =  393   doc =  sportsguy33ummmhavingsometimewarnerproblems
# id doc =  394   doc =  youguysseethiswhydoestimewarnerhavetosucksomuchassreallywishicouldgetuverseatmyapartmenthttpbitlys594j
# id doc =  395   doc =  rtsportsguy33theupsidetotimewarnerunhelpfulphoneoperatorssuperslowonsiteservicecrapthatsnotanupside
# id doc =  396   doc =  rtsportsguy33newtimewarnerslogantimewarnerwherewemakeyoulongforthedaysbeforecable
# id doc =  397   doc =  confirmeditstimewarnersfaultnotfacebooksthatfbistakingabout3minutestoloadsotemptedtoswitchtoverizon
# id doc =  398   doc =  sportsguy33timewarnerepicfail
# id doc =  399   doc =  lawsontoheadnewedgehongkonghttpbitlyxlqsdbusinesschina
# id doc =  400   doc =  weirdpianoguitarhouseinchinahttpu2sme72i8
# id doc =  401   doc =  sendusyourgmchevyphotoshttptinyurlcomluzkpq
# id doc =  402   doc =  iknowhowsadisthatrtcaseymercier1stdayofhurricaneseasonthatslessscareythangovttakingovergm
# id doc =  403   doc =  gmfilesbankruptcynotagoodsign
# id doc =  404   doc =  yankeeswonmetslostitsagoodday
# id doc =  405   doc =  mydentistappttodaywasactuallyquiteenjoyable
# id doc =  406   doc =  ihatetheeffingdentist
# id doc =  407   doc =  stevemoaklerihadadentistapptthismorningandhadthesameconversation
# id doc =  408   doc =  kirstiealleyihategoingtothedentist
# id doc =  409   doc =  ihatethedentistwhoinventedthemanyways
# id doc =  410   doc =  thisdentistsofficeiscold
# id doc =  411   doc =  checkthisvideooutdavidafterdentisthttpbitly47aw2
# id doc =  412   doc =  firstdentistappointmentinyearsonwednesdaypossibly
# id doc =  413   doc =  tomshanahanslatestcolumnonsdsuanditsncaabaseballregionalappearancehttpowlyaxhu
# id doc =  414   doc =  baseballamericacomblogbaseballamericaprospectsblogbloghttpbitlyett8a
# id doc =  415   doc =  portlandcitypoliticsmayundobaseballparkhttptinyurlcomlpjquj
# id doc =  416   doc =  rtwatersiswebcamercedswaterbottledbysafewayresoldataprofitwellsaredryingupacrossthecountyhttptinyurlcommb573s
# id doc =  417   doc =  droppedherbroccoliwalkinghomefromsafeway
# id doc =  418   doc =  ronjonwedonthavesafeway
# id doc =  419   doc =  justappliedatsafewayyeeeee
# id doc =  420   doc =  safewayplaceisanightmarerightnowbumming
# id doc =  421   doc =  atsafewaywithdad
# id doc =  422   doc =  hatesafewayselectgreenteaicecreamboughttwocartonswhatawasteofmoneygt
# id doc =  423   doc =  safewayofferingmobilecouponshttpbitlyonh7w
# id doc =  424   doc =  philliesdrivinginthecadillacwiththetopdownincaliwin53httptinyurlcomnzcjqa
# id doc =  425   doc =  savedmoneybyoptingforgrocerystoretripandstockingfoodinhotelroomfridgevseatingouteverynightwhileoutoftown
# id doc =  426   doc =  loungingaroundeatingtacobellandwatchingncisbeforeworktonightneedhelpstayingawake
# id doc =  427   doc =  eatingbreakfastandthenschool
# id doc =  428   doc =  stillhungryaftereating
# id doc =  429   doc =  10tipsforhealthyeatingresultsbyfitnessblogfitnesshttpbitly62gfn
# id doc =  430   doc =  withtheboyfriendeatingaquesadilla
# id doc =  431   doc =  eatingdinnermeatchipsandrisotto
# id doc =  432   doc =  gotanewpairofnikeshoespicsuplater
# id doc =  433   doc =  nikesbblazerhighacgcustombraddouglashttptimesurlat45a448
# id doc =  434   doc =  nikerocksimsupergratefulforwhativedonewiththemamp
# id doc =  435   doc =  nikeairyeezykhakipinkcolorwayreleasehttpsharesbjfn
# id doc =  436   doc =  evelynbyrnehaveyoutriednikevaddictive
# id doc =  437   doc =  erickostonthatlooksanawfullotlikeoneofnikesprivatejetsimjustsayin
# id doc =  438   doc =  theniketrainingclubbetaiphoneapplooksveryinteresting
# id doc =  439   doc =  argghhhhwhywontmyjqueryappearinsafaribadsafari
# id doc =  440   doc =  devsnippetsjquerytoolsjavascriptuicomponentsforthewebhttpinblogsorggohfuqt
# id doc =  441   doc =  allaboutajaxjquerycssjavascriptandmoremanyexampleshttpajaxiancom
# id doc =  442   doc =  imreadytodropthepretensesiamforeverinlovewithjqueryandiwanttomarryitsorryladiesthisnerdisjqueryspokenforjs
# id doc =  443   doc =  thisiscoldiwaslookingatgoogleschartvisualizationapiandfoundthisjquerywrapperfortheapihttptinyurlcommq52bq
# id doc =  444   doc =  ispentmostofmydayreadingajquerybooknowtostartdrinkingsomedeliriumtremens
# id doc =  445   doc =  jqueryselectorshttpcodylindleycomjqueryselectors
# id doc =  446   doc =  howtoimplementanewstickerwithjqueryandtenlinesofcodehttpbitlycznfj
# id doc =  447   doc =  whatsbuffetdoingwarrenbuffettkicksbuttinbattleofthebootspostedbyalexcrippehttpbitlyauizo
# id doc =  448   doc =  superinvestorsagreatweekendreadherefromwarrenbuffetoldiebutagoodiehttptinyurlcomoqxgga
# id doc =  449   doc =  imtrulybraindeadicouldntcomeupwithwarrenbuffetsnametosavemysoul
# id doc =  450   doc =  readingmichaelpalinbookthepythonyearsgreatbookialsorecommendwarrenbuffetamp
# id doc =  451   doc =  imeanimdownwithnotredameifihavetoitsagoodschoolidbeclosertodanidenjoyit
# id doc =  452   doc =  icantwatchtvwithoutativoandafteralltheseyearsthetimewarnerdvrstillsuckshttpwwwdavehittcommarch03twdvrhtml
# id doc =  453   doc =  idsaysomesportswritersareidiotsforsayingrogerfedererisoneofthebesteverintennisrogerfedereristhebesteverintennis
# id doc =  454   doc =  istilllovemykindle2butreadingthenewyorktimesonitdoesnotfeelnaturalimissthebloomingdaleads
# id doc =  455   doc =  ilovemykindle2nomorestacksofbookstotripoveronthewaytotheloo
# id doc =  456   doc =  althoughtodayskeynoterockedforeverygreatannouncementatamp
# id doc =  457   doc =  sheridanmarfilitsnotsomuchmyobsessionwithcellphonesbuttheiphoneimaslavetoatamp
# id doc =  458   doc =  freitasmohiseeithoughtatamp
# id doc =  459   doc =  plipwheredidyoureadabouttetheringsupportphiljustatamp
# id doc =  460   doc =  fuzzballismorefunthanatamp
# id doc =  461   doc =  todayisagooddaytodislikeatamp
# id doc =  462   doc =  gotmywavesandboxinviteextraexcitedtoobadihaveclassnowbutillplaywithitsoonenoughio2009wave
# id doc =  463   doc =  lookslikesummizehasgonedowntoomanytweetsfromwwdcperhaps
# id doc =  464   doc =  ihopethegirlatworkbuysmykindle2
# id doc =  465   doc =  missedthisinsightfilledmaycolumnonesmartguylookingcloselyatwhyhesimpressedwithkindle2httpbitlyi0peywroush
# id doc =  466   doc =  sklososkythankssomuchfromoneofyourveryhappykindle2winners
# id doc =  467   doc =  manikindadislikeapplerightnowcaseinpointtheiphone3gswishtherewasavideorecorderapppleasehttpbitlydzm1t
# id doc =  468   doc =  cwong08ihaveakindle2amp
# id doc =  469   doc =  thekindle2seemsthebestereaderbutwillitworkintheukandwherecanigetone
# id doc =  470   doc =  ihaveagoogleaddictionthankyouforpointingthatoutannamartin123hahaha
# id doc =  471   doc =  ruby_gemmyprimarydebitcardisvisaelectron
# id doc =  472   doc =  offtothebanktogetmynewvisaplatinumcard
# id doc =  473   doc =  dearestgoogleyourichbastardsthevisacardyousentmedoesntworkwhyscrewalittleguylikeme
# id doc =  474   doc =  hasadatewithbobbyflayandgutfierifromfoodnetwork
# id doc =  475   doc =  excitedaboutseeingbobbyflayandguyfieritomorrowatthegreatamericanfoodamp
# id doc =  476   doc =  gonnagoseebobbyflay2moroatshorelineeatanddrinkgonnabegood
# id doc =  477   doc =  cantwaitforthegreatamericanfoodandmusicfestivalatshorelinetomorrowmmmkatzpastramiandbobbyflayyesplease
# id doc =  478   doc =  mydadwasinnyforadayweateatmesagrilllastnightandmetbobbyflaysomuchfunexcepticompletelylostmyvoicetoday
# id doc =  479   doc =  fightingwithlatexagain
# id doc =  480   doc =  iheartseverusweloveyoutooanddontwantyoutodielatexthedevil
# id doc =  481   doc =  7hours7hoursofinkscapecrashingnormallysolidasarock7hoursoflatexcomplainingattheslightestthingicanttakeanymore
# id doc =  482   doc =  howtotrackiranwithsocialmediahttpbitly2boqu
# id doc =  483   doc =  shitshittingthefaninirancrazinessindeediranelection
# id doc =  484   doc =  mondayalreadyiranmayimplodekitchenisadisasterannagossseemshappysebuloushadaniceweekendandgoldpandaisgreatwhoop
# id doc =  485   doc =  twitterstockbuzzaaples_fspyspxpalmupdated1200pm
# id doc =  486   doc =  gettingreadytotestoutsomeburgerreceipesthisweekendbobbyflayhassomegreatreceipestotrythanksbobby
# id doc =  487   doc =  johncmayerisbobbyflayjoiningyou
# id doc =  488   doc =  ilamsoinlovewithbobbyflayheismyfavoritertterrysimpsonbflayyouneedaplaceinphoenixwehavegreatpeppershere
# id doc =  489   doc =  ijustcreatedmyfirstlatexfilefromscratchthatdidntworkoutverywellseeamandabittneritsagreattimewaster
# id doc =  490   doc =  usinglinuxandlovingitsomuchnicerthanwindowslookingforwardtousingthewysiwyglatexeditor
# id doc =  491   doc =  afterusinglatexalotanyothertypesetmathematicsjustlookshideous
# id doc =  492   doc =  askprogramminglatexorindesignsubmittedbycalcio1link1commenthttptinyurlcommyfmf7
# id doc =  493   doc =  onthatnoteihatewordihatepagesihatelatexthereisaiditihatelatexallyoutexn3rdscancomekillmenow
# id doc =  494   doc =  ahhhbackinarealtexteditingenvironmentilt
# id doc =  495   doc =  troubleiniraniseehmmiraniransofarawayflockofseagullsweregeopoliticallycorrect
# id doc =  496   doc =  readingthetweetscomingoutofiranthewholethingisterrifyingandincrediblysad

# %%
# creation of k-shingling
k_shingling_carac, shingle_hash = k_shingling_caractere(dictionnary_doc_1, size_shingle)

# %%
sike_k_shingling = [i for i in range(100)]
execution_time = list()
number_of_k_shingle_different = list()
for i in sike_k_shingling:
    
    start_time = timer(None)
    k_shingling_carac, shingle_hash = k_shingling_caractere(dictionnary_doc_1, i+1)
    
    thour, tmin, tsec = timer(start_time)
    execution_time.append(thour*3600+tmin*60 + tsec)
    number_of_k_shingle_different.append(len(shingle_hash))

# %%
plt.figure(figsize=(15,15))
# Area plot
plt.xlabel('SIZE OF K-SHINGLES')
plt.ylabel('TIME(s)')
plt.title('SIZE K-SHINGLE')
plt.fill_between(sike_k_shingling, execution_time)
plt.savefig('execution_time.png')
plt.show()

# %%
plt.figure(figsize=(15,15))
# Area plot
plt.xlabel('SIZE K SHINGLE')
plt.ylabel('NUMBER OF K SHINGLES')
plt.title('NUMBER OF DIFFERENT K SHINGLES')
plt.fill_between(sike_k_shingling, number_of_k_shingle_different)
plt.savefig('number_of_k_shingle_different.png')
plt.show()

# %%
# creation of k-shingling
k_shingling_carac, shingle_hash = k_shingling_caractere(dictionnary_doc_1, size_shingle)

# %%
# we create number_perm of permutation function
permutation_functions = dict()
for i in range(number_hash_function):
    permutation_functions[i] = deepcopy(shingle_hash)
    shuffle(permutation_functions[i])

# %%
# build the mini hashing matrix
signature_matrix = build_min_hashing_matrix(k_shingling_carac, shingle_hash, permutation_functions)

# %%
for i in signature_matrix:
    print("id hash function = ",i,"  resul = ",signature_matrix[i][0:9])

# %%
#Build the similarity matrix
testest = build_similarity_matrix(signature_matrix)

# %%
array_similarity_ = list()
similarity_threshold = [0.01*(i+1) for i in range(100)]

# %%
#number_hash_function = 10  and  size_shingle = 5
for kk in similarity_threshold:
    numb_similarity = 0
    for i in range(len(testest[0])-1):
        for j in range(i+1,len(testest[0])):
            if testest[i][j]>kk:
                numb_similarity+=1
    array_similarity_.append(numb_similarity)

# %%
plt.figure(figsize=(15,15))
# Area plot
plt.xlabel('SIMILARITY THRESHOLD')
plt.ylabel('ARRAY SIMILARITY')
plt.title('NUMBER SIMILARITY PER THRESHOLD')
plt.fill_between(similarity_threshold, array_similarity_)
plt.savefig('number_of_similarity_per_threshold.png')
plt.show()

# %%
#Build the locality sensistive hashing matrix
locality_sensitive_hashing_matrix = locality_sensitive_hashing(signature_matrix,number_of_bande,shingle_hash)

# %%
array_similarity_ = list()
array__number_locality_sensitive_ = list()
similarity_threshold = [0.01*(i+1) for i in range(100)]

# %%
#number_hash_function = 10  and  size_shingle = 5
for kk in similarity_threshold:
    numb_similarity = 0
    number_loclity = 0
    for i in range(len(testest[0])-1):
        for j in range(i+1,len(testest[0])):
            if testest[i][j]>kk:
                numb_similarity+=1
            if(locality_sensitive_hashing_matrix[i][j]>kk):
                number_loclity+=1
                
    array__number_locality_sensitive_.append(number_loclity)
    array_similarity_.append(numb_similarity)

# %%
fig = plt.figure(figsize=(15,15))
# Area plot
plt.xlabel('SIMILARITY THRESHOLD')
plt.ylabel('ARRAY SIMILARITY')
plt.title('NUMBER SIMILARITY PER THRESHOLD')
plt.plot(similarity_threshold, array_similarity_, label='NUMBER SIMILARITY PER THRESHOLD')
plt.plot(similarity_threshold, array__number_locality_sensitive_, label='NUMBER OF LOCALITY PER THRESHOLD')
plt.fill_between(similarity_threshold, array_similarity_)
plt.fill_between(similarity_threshold, array__number_locality_sensitive_)
plt.savefig('123.png')
plt.legend(loc='best')
plt.show()

# %%
# locality sensitive hashing matrix
for i in range(len(locality_sensitive_hashing_matrix[0])-1):
    for j in range(i+1,len(locality_sensitive_hashing_matrix[0])-i):
        if(locality_sensitive_hashing_matrix[i][j]>0):
            print(i,"  ===  ",j,"  ==  ",locality_sensitive_hashing_matrix[i][j])

# %%
#number_hash_function = 10  and  size_shingle = 5
for i in range(len(signature_matrix[0])-1):
    for j in range(i+1,len(signature_matrix[0])):
        if jaccard_similarity(k_shingling_carac[i], k_shingling_carac[j])>threshold_simmilarity:
            print(i,"    ",j,"    ",jaccard_similarity(k_shingling_carac[i], k_shingling_carac[j]))
